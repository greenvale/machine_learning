# %%
from MNIST import *

# %%
batch_size = 32
lr = 0.01
num_batches = 10_000
val_freq = 200

model = Model()

train_model(model, batch_size, lr, num_batches, val_freq, True)
acc = test_model(model)
print(f"accuracy={acc}")
# Out:
# accuracy=0.9667

# %% [markdown]
# # Convolution kernel weights

# %% [markdown]
# ### Convolutional layer 1

# %%
imshow_3d(model.conv1.weight.moveaxis(1,0)[0])

# %% [markdown]
# ### Convolutional layer 2

# %%
imshow_3d(model.conv2.weight.moveaxis(1,0)[0])

# %% [markdown]
# # Cross-section of network

# %%
idx = 0
model.forward(testset.data[idx].unsqueeze(0).unsqueeze(1)/255.0)
# Out:
# tensor([[9.6878e-07, 3.2644e-10, 3.2415e-04, 1.8436e-04, 1.8481e-10, 8.3255e-07,
#          2.1151e-12, 9.9902e-01, 7.9872e-06, 4.6563e-04]],
#        grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# ### Input image

# %%
imshow_3d(testset.data[idx])

# %% [markdown]
# ### After first conv layer

# %%
imshow_3d(model.a1[0])

# %% [markdown]
# ### After first max pool

# %%
imshow_3d(model.b1[0])

# %% [markdown]
# ### After second conv layer

# %%
imshow_3d(model.a2[0])

# %% [markdown]
# ### After second max pool

# %%
imshow_3d(model.b2[0])
